# %% [markdown]
# import libraries

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder

# %% [markdown]
# import ds

# %%
dataset =pd.read_csv('C:/Users/Prachi Yadav/Desktop/TY/projects/python/archive (12)/jobs_in_data.csv')
dataset
# Out:
#       work_year                 job_title                    job_category  \
# 0          2023      Data DevOps Engineer                Data Engineering
# 1          2023            Data Architect  Data Architecture and Modeling
# 2          2023            Data Architect  Data Architecture and Modeling
# 3          2023            Data Scientist       Data Science and Research
# 4          2023            Data Scientist       Data Science and Research
# ...         ...                       ...                             ...
# 9350       2021           Data Specialist    Data Management and Strategy
# 9351       2020            Data Scientist       Data Science and Research
# 9352       2021  Principal Data Scientist       Data Science and Research
# 9353       2020            Data Scientist       Data Science and Research
# 9354       2020     Business Data Analyst                   Data Analysis
#
#      salary_currency  salary  salary_in_usd employee_residence  \
# ...

# %%
dataset.info()   #all info of ds
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9355 entries, 0 to 9354
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   work_year           9355 non-null   int64
#  1   job_title           9355 non-null   object
#  2   job_category        9355 non-null   object
#  3   salary_currency     9355 non-null   object
#  4   salary              9355 non-null   int64
#  5   salary_in_usd       9355 non-null   int64
#  6   employee_residence  9355 non-null   object
#  7   experience_level    9355 non-null   object
#  8   employment_type     9355 non-null   object
#  9   work_setting        9355 non-null   object
#  10  company_location    9355 non-null   object
#  11  company_size        9355 non-null   object
# dtypes: int64(3), object(9)
# memory usage: 877.2+ KB

# %% [markdown]
# dealing with null values/

# %%
dataset.isna().sum()
# Out:
# work_year             0
# job_title             0
# job_category          0
# salary_currency       0
# salary                0
# salary_in_usd         0
# employee_residence    0
# experience_level      0
# employment_type       0
# work_setting          0
# company_location      0
# company_size          0
# dtype: int64

# %% [markdown]
# drop null values

# %%
ndataset = dataset.dropna()

# %%
X = dataset.iloc[:,:-1]   #for dependent variable 
Y = dataset.iloc[:,-1:]  #for independent variable

# %% [markdown]
# dealing with categorical values

# %%
#for encoding labeled data into numbers
lEncoder = LabelEncoder()     #create object of class

# %%
X.iloc[:,0] = lEncoder.fit_transform(X.iloc[:,0])

# %%
X
# Out:
#       work_year                 job_title                    job_category  \
# 0            42      Data DevOps Engineer                Data Engineering
# 1            41            Data Architect  Data Architecture and Modeling
# 2            41            Data Architect  Data Architecture and Modeling
# 3            69            Data Scientist       Data Science and Research
# 4            69            Data Scientist       Data Science and Research
# ...         ...                       ...                             ...
# 9350         71           Data Specialist    Data Management and Strategy
# 9351         69            Data Scientist       Data Science and Research
# 9352        114  Principal Data Scientist       Data Science and Research
# 9353         69            Data Scientist       Data Science and Research
# 9354         21     Business Data Analyst                   Data Analysis
#
#      salary_currency  salary  salary_in_usd employee_residence  \
# ...

# %% [markdown]
# onehotencoder requires that all values are integers and not strings so encode all possible values to integers

# %% [markdown]
# split ds into training and testing dataset

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.25,random_state=0)

# %% [markdown]
# feature scaling

# %%
sc_x = StandardScaler()

# %%
X_train = sc_x.fit_transform(X_train)
X_test = sc_x.fit_transform(X_test)

# %% [markdown]
# scaling

# %%
sc_x = StandardScaler()

# %%
#fit transform

# %%
X['salary'] = sc_x.fit_transform(X['salary'].values.reshape(-1,1))

# %%
X
# Out:
#       work_year                 job_title                    job_category  \
# 0            42      Data DevOps Engineer                Data Engineering
# 1            41            Data Architect  Data Architecture and Modeling
# 2            41            Data Architect  Data Architecture and Modeling
# 3            69            Data Scientist       Data Science and Research
# 4            69            Data Scientist       Data Science and Research
# ...         ...                       ...                             ...
# 9350         71           Data Specialist    Data Management and Strategy
# 9351         69            Data Scientist       Data Science and Research
# 9352        114  Principal Data Scientist       Data Science and Research
# 9353         69            Data Scientist       Data Science and Research
# 9354         21     Business Data Analyst                   Data Analysis
#
#      salary_currency    salary  salary_in_usd employee_residence  \
# ...
